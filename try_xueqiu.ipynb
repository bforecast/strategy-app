# %%
import pysnowball as ball
import streamlit as st

token = ball.set_token(f'xq_a_token={st.secrets["xueqiu"]["xq_a_token"]}')

# %%
ball.earningforecast('sh601318')
# Out:
# {'list': [{'eps': 5.62,
#    'roe': None,
#    'pb': 0.92,
#    'pe': 7.82,
#    'forecast_year': '2022'},
#   {'eps': 6.61, 'roe': None, 'pb': 0.84, 'pe': 6.65, 'forecast_year': '2023'}]}

# %%
ball.main_indicator('sh601318')
# Out:
# {'data': {'items': [{'asset_liab_ratio': 89.5545,
#     'pledge_ratio': 3.18,
#     'net_profit_atsopc_yoy': 3.91,
#     'operating_income_yoy': -3.7044,
#     'goodwill_in_net_assets': 2.729,
#     'basic_eps': 3.45,
#     'net_selling_rate': 11.7098,
#     'avg_roe': 7.2,
#     'gross_selling_rate': None,
#     'float_shares': 10832664498,
#     'pb': 0.896,
#     'np_per_share': 46.43,
#     'float_market_capital': 450422189827.0,
#     'total_revenue': 612102000000.0,
#     'market_capital': 760092437828.0,
#     'pe_ttm': 7.317,
#     'dividend': 2.42,
#     'currency': 'CNY',
#     'dividend_yield': 5.82,
#     'net_profit_atsopc': 60273000000.0,
#     'total_shares': 18280241410,
#     'report_date': '2022中报'}]},
#  'error_code': 0,
#  'error_description': ''}

# %%
watch_list = ball.watch_list()
watch_list
# Out:
# {'data': {'cubes': [{'id': -120,
#     'name': '全部',
#     'order_id': -50,
#     'category': 3,
#     'include': False,
#     'symbol_count': 79,
#     'type': -1},
#    {'id': -27,
#     'name': '沪深',
#     'order_id': -40,
#     'category': 3,
#     'include': False,
#     'symbol_count': 51,
#     'type': -1},
#    {'id': -26,
#     'name': '港股',
#     'order_id': -30,
#     'category': 3,
#     'include': False,
#     'symbol_count': 15,
#     'type': -1},
#    {'id': -25,
#     'name': '美股',
#     'order_id': -20,
#     'category': 3,
#     'include': False,
#     'symbol_count': 13,
#     'type': -1},
#    {'id': -24,
#     'name': '我的',
#     'order_id': -10,
#     'category': 3,
#     'include': False,
#     'symbol_count': 6,
#     'type': -1}],
#   'funds': [{'id': -110,
#     'name': '全部',
#     'order_id': -30,
#     'category': 2,
#     'include': False,
#     'symbol_count': 8,
#     'type': -1},
#    {'id': -17,
#     'name': '基金',
#     'order_id': -20,
# ...

# %%
watch_list['data']['stocks']
# Out:
# [{'id': -1,
#   'name': '全部',
#   'order_id': -50,
#   'category': 1,
#   'include': False,
#   'symbol_count': 237,
#   'type': -1},
#  {'id': -5,
#   'name': '沪深',
#   'order_id': -40,
#   'category': 1,
#   'include': False,
#   'symbol_count': 94,
#   'type': -1},
#  {'id': -7,
#   'name': '港股',
#   'order_id': -30,
#   'category': 1,
#   'include': False,
#   'symbol_count': 50,
#   'type': -1},
#  {'id': -6,
#   'name': '美股',
#   'order_id': -20,
#   'category': 1,
#   'include': False,
#   'symbol_count': 89,
#   'type': -1},
#  {'id': -4,
#   'name': '模拟',
#   'order_id': -10,
#   'category': 1,
#   'include': False,
#   'symbol_count': 6,
#   'type': -1},
#  {'id': 0,
#   'name': 'pool',
#   'order_id': 1,
#   'category': 1,
#   'include': False,
#   'symbol_count': 0,
#   'type': 1,
#   'created_at': 1629123041798,
#   'updated_at': 1629123041798}]

# %%
watch_stock = ball.watch_stock(-1)['data']
watch_stock['stocks']
# Out:
# [{'symbol': '00772',
#   'name': '阅文集团',
#   'type': 30,
#   'remark': '',
#   'exchange': 'HK',
#   'created': 1666014297269,
#   'category': 1},
#  {'symbol': 'SH600089',
#   'name': '特变电工',
#   'type': 11,
#   'remark': '',
#   'exchange': 'SH',
#   'created': 1656473914367,
#   'category': 1},
#  {'symbol': 'META',
#   'name': 'Meta Platforms',
#   'type': 0,
#   'remark': '',
#   'exchange': 'NASDAQ',
#   'created': 1654770247255,
#   'category': 1},
#  {'symbol': '02423',
#   'name': '贝壳-W',
#   'type': 30,
#   'remark': '',
#   'exchange': 'HK',
#   'created': 1652085636082,
#   'category': 1},
#  {'symbol': 'SZ159939',
#   'name': '信息技术ETF',
#   'type': 13,
#   'remark': '',
#   'exchange': 'SZ',
#   'created': 1650004356547,
#   'category': 1},
#  {'symbol': '00941',
#   'name': '中国移动',
#   'type': 30,
#   'remark': '',
#   'exchange': 'HK',
#   'created': 1648779689014,
#   'category': 1},
#  {'symbol': 'TLRY',
#   'name': 'Tilray Brands',
#   'type': 0,
#   'remark': '',
# ...

# %%
len(watch_stock['stocks'])
# Out:
# 235

# %%
ball.index_weight_top10("399006")
# Out:
# {'code': '200',
#  'msg': 'Success',
#  'data': {'updateDate': None,
#   'top5Sum': None,
#   'top10Sum': None,
#   'weightList': None},
#  'success': True}

# %%
ball.index_perf_7("399967")
# Out:
# {'code': '200',
#  'msg': 'Success',
#  'data': [{'tradeDate': '20221011',
#    'indexCode': '399967',
#    'indexNameCnAll': '中证军工指数',
#    'indexNameCn': '中证军工',
#    'indexNameEnAll': 'CSI National Defense Industry Index',
#    'indexNameEn': 'CSI National Defense',
#    'open': 10907.97,
#    'high': 11013.24,
#    'low': 10828.71,
#    'close': 10960.95,
#    'change': 47.02,
#    'changePct': 0.43,
#    'tradingVol': 5.61,
#    'tradingValue': 126.51,
#    'consNumber': 68.0,
#    'peg': 46.12},
#   {'tradeDate': '20221012',
#    'indexCode': '399967',
#    'indexNameCnAll': '中证军工指数',
#    'indexNameCn': '中证军工',
#    'indexNameEnAll': 'CSI National Defense Industry Index',
#    'indexNameEn': 'CSI National Defense',
#    'open': 10943.43,
#    'high': 11188.98,
#    'low': 10697.7,
#    'close': 11186.5,
#    'change': 225.55,
#    'changePct': 2.06,
#    'tradingVol': 7.98,
#    'tradingValue': 178.97,
#    'consNumber': 68.0,
#    'peg': 47.08},
#   {'tradeDate': '20221013',
# ...
